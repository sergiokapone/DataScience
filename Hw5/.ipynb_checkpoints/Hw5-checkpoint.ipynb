# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Збір даних
#
# Перш за все, потрібно зберемо дані з акселерометра мобільного телефону.

# %%
from pathlib import Path
activities = ['idle', 'running', 'stairs', 'walking']
data_collections = []

for index, activity in enumerate(activities, start=1):
    activity_path = Path('data') / activity  
    csv_files = list(activity_path.glob('*.csv'))  
    df = pd.concat((pd.read_csv(file) for file in csv_files), ignore_index=True)
    df['activity'] = index
    data_collections.append(df)

data = pd.concat(data_collections, ignore_index=True)

# %% [markdown]
# # Підготовка даних
#
# Підготовка включає очищення, нормалізацію та вибір релевантних ознак. Також, треба розрахувати часові ознаки, такі як середнє значення, дисперсія, середнє квадратичне відхилення і т. д. для поліпшення результатів.

# %%
data['min'] = data[measurements].min(axis=1)
data['mean'] = data[measurements].mean(axis=1)
data['max'] = data[measurements].max(axis=1)
data['std'] = data[measurements].std(axis=1)
data['range'] = data[measurements].max(axis=1) - data[measurements].min(axis=1)
data
# Out:
#         accelerometer_X  accelerometer_Y  accelerometer_Z  activity  \
# 0              1.000776         4.616021         8.576031         1
# 1              0.718261         4.209007         8.446744         1
# 2             -0.909797        -0.282516         9.203311         1
# 3              5.099650         0.148441         8.418014         1
# 4              1.762132        -0.162806         9.251195         1
# ...                 ...              ...              ...       ...
# 193855         5.109226       -15.452178        -1.470040         4
# 193856         6.373365       -11.741165        -8.226476         4
# 193857         3.289633        -9.993398        -0.383072         4
# 193858        -2.978387        -3.050213         1.273715         4
# 193859        -4.347870        -9.926360        -1.642422         4
#
#               min      mean       max        std      range
# 0        1.000776  4.730943  8.576031   3.788935   7.575255
# ...

# %% [markdown]
# # Вибір моделей
#
# Викоритовуємо бібліотеку `scikit-learn` для створення моделей машинного навчання, таких як `SVM` та випадковий ліс.

# %% [markdown]
# # Навчання та оцінка моделей
#
# Розділимо набір даних на тренувальні та тестові дані.
#
# Навчіть моделі на тренувальних даних та оцініть їх точність, використовуючи тестові дані. Ви можете використовувати метрики якості, такі як точність, відзив, точність та інші, для порівняння результатів обох моделей.
